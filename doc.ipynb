# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler


# Load data
features = pd.read_csv('features.csv')
targets = pd.read_csv('targets.csv')

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(features, targets, test_size=0.2, random_state=42)

# Normalize the data
feature_scaler = StandardScaler()
X_train = feature_scaler.fit_transform(X_train)
X_test = feature_scaler.transform(X_test)

target_scaler = StandardScaler()
y_train = target_scaler.fit_transform(y_train)
y_test = target_scaler.transform(y_test)

# %%
# Define the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(3)  # Output layer for XYZ coordinates
])

# Compile the model
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
# Out:
# c:\Users\abdul\Projects\senior-design-2\.venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Fit the model
history = model.fit(X_train, y_train, epochs=200, validation_split=0.2, batch_size=32, verbose=1)
# Out:
# Epoch 1/200
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.6686 - mae: 0.5790 - val_loss: 0.6716 - val_mae: 0.5808
# Epoch 2/200
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 1s 938us/step - loss: 0.6634 - mae: 0.5751 - val_loss: 0.6719 - val_mae: 0.5809
# Epoch 3/200
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6655 - mae: 0.5755 - val_loss: 0.6719 - val_mae: 0.5809
# Epoch 4/200
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 1s 926us/step - loss: 0.6684 - mae: 0.5780 - val_loss: 0.6712 - val_mae: 0.5806
# Epoch 5/200
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6656 - mae: 0.5764 - val_loss: 0.6716 - val_mae: 0.5808
# Epoch 6/200
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 1s 985us/step - loss: 0.6656 - mae: 0.5756 - val_loss: 0.6715 - val_mae: 0.5807
# Epoch 7/200
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 1s 962us/step - loss: 0.6698 - mae: 0.5786 - val_loss: 0.6713 - val_mae: 0.5806
# Epoch 8/200
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 1s 957us/step - loss: 0.6664 - mae: 0.5766 - val_loss: 0.6716 - val_mae: 0.5807
# ...

# %%
# Predict and inverse transform
predictions = model.predict(X_test)
predictions = target_scaler.inverse_transform(predictions)

# Reverse scaling for y_test for evaluation
y_test = target_scaler.inverse_transform(y_test)

# Calculate MAE
mae = mean_absolute_error(y_test, predictions)
print(f'Mean Absolute Error: {mae}')
# Out:
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step
# Mean Absolute Error: 5.392545761623395

# %%
from sklearn.metrics import mean_absolute_error

# Calculate Mean Absolute Error for the predicted values
mae = mean_absolute_error(y_test, predictions)
mae
# Out:
# np.float64(5.392545761623395)
